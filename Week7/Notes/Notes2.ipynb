# %% [markdown]
# ---------

# %% [markdown]
# # **Matplotlib**

# %% [markdown]
# --------------------------------
# Matplotlib is a comprehensive data visualization library for the Python programming language. It provides a wide range of tools for creating various types of static, animated, and interactive plots and charts.

# %% [markdown]
# --------------------------
# -------------------------
# ## **Types of Plots**
# -------------------------
# -------------------------

# %% [markdown]
# <p align="center">
#   <img src="https://datascienceplus.com/wp-content/uploads/2018/07/Data-Visualization-1.png" width="700" border="5px  black"/>
# </p>

# %% [markdown]
# -----------------
# ------------------
# ## **Install Matplotlib**
# ------------------
# -------------------

# %%
# Instalación de Biblioteca desde Jupyter 
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/162.3 kB 1.4 MB/s eta 0:00:01
#      ------- ------------------------------- 30.7/162.3 kB 1.4 MB/s eta 0:00:01
#      --------------------- --------------- 92.2/162.3 kB 751.6 kB/s eta 0:00:01
#      ------------------------ ----------- 112.6/162.3 kB 819.2 kB/s eta 0:00:01
#      ------------------------------- ---- 143.4/162.3 kB 774.0 kB/s eta 0:00:01
#      ------------------------------------ 162.3/162.3 kB 608.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.6 MB 4.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/7.6 MB 3.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/7.6 MB 3.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/7.6 MB 1.7 MB/s eta 0:00:05
# ...

# %%
# Check matplotlib Versions 
import matplotlib 
matplotlib.__version__
# Out:
# '3.8.3'
